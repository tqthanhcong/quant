# %% [markdown]
# insert data raw to data/raw

# %%
import os, sys
sys.path.insert(0, os.path.abspath("../../src"))  # from notebooks/one_off -> system/src

# %%
import importlib
import data.ingestor as mylib
importlib.reload(mylib)
# Out:
# <module 'data.ingestor' from '/workspaces/quant/system/src/data/ingestor.py'>

# %%
from data.ingestor import get_data_by_symbols_and_save

# %%
get_data_by_symbols_and_save(symbols=['HPG'], csv_path='../../data/raw/data.csv', start='2025-09-01', end='2025-09-30')
# Out:
# Data saved to ../../data/raw/data.csv. Total rows now: 3920.

# %%
import pandas as pd
df = pd.read_csv('../../data/raw/data.csv')
df.head()
# Out:
#          time  open  high   low  close   volume symbol
# 0  2010-01-04  1.47  1.49  1.47   1.49   603120    HPG
# 1  2010-01-05  1.56  1.56  1.49   1.56  1203080    HPG
# 2  2010-01-06  1.55  1.61  1.54   1.61  1771660    HPG
# 3  2010-01-07  1.64  1.68  1.61   1.66  1535800    HPG
# 4  2010-01-08  1.70  1.70  1.59   1.59   909010    HPG
